# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#read file It is a file with data added in blank cells
df = pd.read_excel("DS4PM F22 Homework_HP.xls")

# %%
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year     Location  \
# 0      Honda    Accord               Dealer  22350  2018     new york
# 1      Honda    Accord               Dealer  24788  2018  Bellevue WA
# 2      Honda    Accord               Dealer  19254  2016   Butler, PA
# 3      Honda    Accord               Dealer  13896  2014      Wexford
# 4      Honda    Accord               Dealer  29980  2020  Indiana, PA
# ..       ...       ...                  ...    ...   ...          ...
# 517    Honda    Accord               Dealer  20000  2017           PA
# 518    Honda    Accord               Dealer  15987  2015           PA
# 519    Honda    Accord               Dealer  13589  2014           PA
# 520    Honda    Accord               Dealer  14988  2011           PA
# 521    Honda    Accord               Dealer  16988  2014           PA
#
#       Mileage    Doors                      Color Transmission  \
# ...

# %%
df = df.assign(count=df.isnull().sum(1))\
       .sort_values(['VIN#', 'count'])\
       .groupby('VIN#', as_index=0).head(1)\
       .drop('count', 1)
# Out:
# /var/folders/ky/rq7qfvdj3fj7j413nz59p_x40000gn/T/ipykernel_47751/2844332093.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.assign(count=df.isnull().sum(1))\

# %%
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 431    Honda    Accord           Individual   6599  2000
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# ..       ...       ...                  ...    ...   ...
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 321    Honda    Accord               Dealer  24738  2018
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 431                               Pittsburgh   92000.0   NaN
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# ...

# %%
df1= pd.read_excel("DS4PM F22 Homework_HP.xls")

# %%
df1
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year     Location  \
# 0      Honda    Accord               Dealer  22350  2018     new york
# 1      Honda    Accord               Dealer  24788  2018  Bellevue WA
# 2      Honda    Accord               Dealer  19254  2016   Butler, PA
# 3      Honda    Accord               Dealer  13896  2014      Wexford
# 4      Honda    Accord               Dealer  29980  2020  Indiana, PA
# ..       ...       ...                  ...    ...   ...          ...
# 517    Honda    Accord               Dealer  20000  2017           PA
# 518    Honda    Accord               Dealer  15987  2015           PA
# 519    Honda    Accord               Dealer  13589  2014           PA
# 520    Honda    Accord               Dealer  14988  2011           PA
# 521    Honda    Accord               Dealer  16988  2014           PA
#
#       Mileage    Doors                      Color Transmission  \
# ...

# %%
df_N1 = df.drop_duplicates(subset=['VIN#'])

# %%
df_N1
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 431    Honda    Accord           Individual   6599  2000
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# ..       ...       ...                  ...    ...   ...
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 321    Honda    Accord               Dealer  24738  2018
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 431                               Pittsburgh   92000.0   NaN
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# ...

# %%
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 431    Honda    Accord           Individual   6599  2000
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# ..       ...       ...                  ...    ...   ...
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 321    Honda    Accord               Dealer  24738  2018
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 431                               Pittsburgh   92000.0   NaN
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# ...

# %%
df = df.drop(df[df['Mileage']<100].index)

# %%
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 431    Honda    Accord           Individual   6599  2000
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# ..       ...       ...                  ...    ...   ...
# 117    Honda    Accord               Dealer  10400  2008
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 431                               Pittsburgh   92000.0   NaN
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# ...

# %%
df=df.dropna(subset=['Mileage'])

# %%
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 431    Honda    Accord           Individual   6599  2000
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# ..       ...       ...                  ...    ...   ...
# 117    Honda    Accord               Dealer  10400  2008
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 431                               Pittsburgh   92000.0   NaN
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# ...

# %%
#Remove years before 2008
df = df.drop(df[df['Year']<2008].index)

# %%
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# 496    Honda    Accord               Dealer  19473  2017
# ..       ...       ...                  ...    ...   ...
# 117    Honda    Accord               Dealer  10400  2008
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# 110      2940 Chenoweth Road Akron, OH 44312   60000.0     4
# ...

# %%
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# 496    Honda    Accord               Dealer  19473  2017
# ..       ...       ...                  ...    ...   ...
# 117    Honda    Accord               Dealer  10400  2008
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# 110      2940 Chenoweth Road Akron, OH 44312   60000.0     4
# ...

# %%
#Remove years after 2018
df = df.drop(df[df['Year']>2018].index)
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# 496    Honda    Accord               Dealer  19473  2017
# ..       ...       ...                  ...    ...   ...
# 117    Honda    Accord               Dealer  10400  2008
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# 110      2940 Chenoweth Road Akron, OH 44312   60000.0     4
# ...

# %%
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# 496    Honda    Accord               Dealer  19473  2017
# ..       ...       ...                  ...    ...   ...
# 117    Honda    Accord               Dealer  10400  2008
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# 110      2940 Chenoweth Road Akron, OH 44312   60000.0     4
# ...

# %%
#Standardize all Door data and add 4 in the blanks as it is majority
df['Doors'] = df['Doors'].replace(['Coupe'],'2')
df['Doors'] = df['Doors'].replace(['4 doors','4 Door', '4 Doors', '4 Door Sedan','5','four'],'4')
df
# Out:
#     Car Make Car Model Dealer or Individual  Price  Year  \
# 434    Honda    Accord           Individual  13245  2012
# 107    Honda    Accord               Dealer   6999  2010
# 110    Honda    Accord               Dealer  16998  2010
# 111    Honda    Accord           Individual  10000  2010
# 496    Honda    Accord               Dealer  19473  2017
# ..       ...       ...                  ...    ...   ...
# 117    Honda    Accord               Dealer  10400  2008
# 197    Honda    Accord               Dealer   8975  2008
# 82     Honda    Accord               Dealer  24757  2017
# 477    Honda    Accord               Dealer  10487  2014
# 12     Honda    Accord           Individual  27000  2017
#
#                                     Location   Mileage Doors  \
# 434                               Pittsburgh  111078.0   NaN
# 107    922 N Croton Ave New Castle, PA 16101  175994.0     4
# 110      2940 Chenoweth Road Akron, OH 44312   60000.0     4
# ...

# %%
df.to_excel('df_final.xls')
# Out:
# /var/folders/ky/rq7qfvdj3fj7j413nz59p_x40000gn/T/ipykernel_47751/242105743.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('df_final.xls')

# %%
#Made edits in excel for blank data and uploaded file (details in project file)
df = pd.read_excel("df_final.xls")
df
# Out:
#      Unnamed: 0 Car Make Car Model Dealer or Individual  Price  Year  \
# 0           434    Honda    Accord           Individual  13245  2012
# 1           107    Honda    Accord               Dealer   6999  2010
# 2           110    Honda    Accord               Dealer  16998  2010
# 3           111    Honda    Accord           Individual  10000  2010
# 4           496    Honda    Accord               Dealer  19473  2017
# ..          ...      ...       ...                  ...    ...   ...
# 290         260    Honda    Accord               Dealer  14990  2009
# 291         117    Honda    Accord               Dealer  10400  2008
# 292         197    Honda    Accord               Dealer   8975  2008
# 293          82    Honda    Accord               Dealer  24757  2017
# 294         477    Honda    Accord               Dealer  10487  2014
#
#                                     Location  Mileage  Doors  \
# 0                                 Pittsburgh   111078      4
# ...

# %%
#To understand the cars in data of car in a year and its mileage
#sns.relplot(x="Price", y="Year", hue="Mileage", data=df)
sns.set(rc = {'figure.figsize':(15,15)})
sns.scatterplot(data = df, x = "Price", y = "Year", hue = "Mileage")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Year'>

# %%
#As per previous scatterplot distribution I was able to understand the Good buying option based on cars which are new and median price with less mileage. 
#Car distribution per year
sns.set(style="ticks")
type_count = df['Year'].value_counts()
plt.figure(figsize=(14, 8))
ax = sns.barplot(x = type_count.index, y = type_count)

# %%
#The above graph shows the amount of cars listed per year which shows the data has highest number of cars in 2017 and 2018
sns.set(style="ticks")
type_count = df['Mileage'].value_counts()
plt.figure(figsize=(14, 8))
ax = sns.barplot(x = type_count, y = type_count.index)

# %%
#As per the data, the average price of cars lies between
